# %% [markdown]
# <a href="https://colab.research.google.com/github/para662/BSC_DPDM/blob/main/ch3_data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data cleaning

# %% [markdown]
# #Missing data

# %% [markdown]
# ### Drop record ที่มี missing ออก

# %% [markdown]
# drop ถ้ามี missing

# %%
df.shape
# Out:
# (913, 23)

# %%
df_drop = df.dropna()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/datap/flooding database.csv'
df = pd.read_csv(file_path)
display(df.head())
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# ...

# %% [markdown]
# drop เฉพาะเกิด missing ออก
#
# - dfo_country
# - dfo_other_country
# - dfo_began
# - dfo_ended
# - dfo_dead
# - dfo_cause	2
# - dfo_severity

# %%
df_drop = df.dropna(subset=['dfo_country', 'dfo_other_country', 'dfo_began', 'dfo_ended',
                            'dfo_dead', 'dfo_cause', 'dfo_severity'])
df_drop.shape
# Out:
# (637, 23)

# %% [markdown]
# #check missing

# %%
df.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ## เติม dummy

# %%
df.isnull()['dfo_other_country']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 908     True
# 909     True
# 910     True
# 911     True
# 912     True
# Name: dfo_other_country, Length: 913, dtype: bool

# %%
df

# %% [markdown]
# ## เติม missing ด้วยค่ากลาง

# %%
df.groupby('dfo_cause').count()
# Out:
#                        system:index  index  threshold_type  glide_index  \
# dfo_cause
# Dam                              13     13              13           11
# Heavy rain                      749    749             749          554
# Snowmelt, Ice, Rain              52     52              52           45
# Tropical Storm, Surge            97     97              97           71
#
#                        dfo_country  dfo_other_country  dfo_centroid_x  \
# dfo_cause
# Dam                             13                 10              13
# Heavy rain                     749                530             749
# Snowmelt, Ice, Rain             52                 45              52
# Tropical Storm, Surge           97                 53              97
#
#                        dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_cause                                                    ...
# Dam                                13         13         13  ...
# ...

# %% [markdown]
# เติม Missing ด้วยค่ากลาง

# %%
df_sever1 = df[df['dfo_severity']==1.0]
df_sever15 = df[df['dfo_severity']==1.5]
df_sever2 = df[df['dfo_severity']==2.0]

# %%
df_sever1 = flood_sever1.fillna('dfo_cause':'Heavy rain')
df_sever15 = flood_sever15.fillna('dfo_cause':'Heavy rain')
df_sever2 = flood_sever2.fillna('dfo_cause':'Tropicak Storm'
# Out:
#   File "/tmp/ipython-input-2322724678.py", line 1
#     df_sever1 = flood_sever1.fillna('dfo_cause':'Heavy rain')
#                                                ^
# SyntaxError: invalid syntax
